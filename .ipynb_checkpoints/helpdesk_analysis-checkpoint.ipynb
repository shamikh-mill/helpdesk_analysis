# %%
import sys
import scipy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
rawdata = pd.DataFrame(pd.read_csv('incident.csv', index_col='number'))
#index_col sets the index column to something other than the normal numerical sequence 
#calendar duration is in minutes 
rawdata.head()
# Out:
#             incident_state            opened_at                    caller_id  \
# number
# INC0000000a         Closed  2014-07-14 17:59:09        Patrick Brown (pab26)
# INC0000006          Closed  2012-05-06 09:52:41  Christopher Smith (smittyc)
# INC0000008          Closed  2012-05-06 10:02:01        Christa Abedi (ca102)
# INC0000009          Closed  2012-05-06 10:03:27          Kirk Rouser (kjr10)
# INC0000013          Closed  2012-05-06 10:06:27       Jeff Gentry (gentr066)
#
#                                short_description       sys_updated_on  \
# number
# INC0000000a  Urgent Workstation Issue DUH or CHC  2014-07-26 00:12:03
# INC0000006          ServiceNow initial incident.  2012-05-08 00:01:10
# INC0000008                     New employee hire  2012-05-09 00:04:07
# INC0000009                  Test Email from Kirk  2012-05-08 00:01:03
# INC0000013                           Test ticket  2012-05-06 10:46:32
#
#                                   assignment_group  calendar_duration  \
# number
# INC0000000a            Device Support-DHTS Reg6-SE              45667
# INC0000006   Support@Duke (ServiceNow App Support)             137309
# INC0000008                  [i]Device Support-DRaH             223326
# INC0000009                        Service Desk-OIT             136656
# INC0000013                Service Desk-Level 1-DRH               2405
#
#                           closed_by
# number
# INC0000000a                     NaN
# INC0000006                      NaN
# INC0000008                      NaN
# INC0000009                      NaN
# INC0000013   Jeff Gentry (gentr066)

# %%
closed_cases = pd.DataFrame(rawdata[rawdata['incident_state'] == "Closed"])
#Need to only look at solved cases! 
closed_cases.head() # don't use print statements, just name of dataframe shows in tables
#calendar_duration currently shows number of seconds!
# Out:
#             incident_state            opened_at                    caller_id  \
# number
# INC0000000a         Closed  2014-07-14 17:59:09        Patrick Brown (pab26)
# INC0000006          Closed  2012-05-06 09:52:41  Christopher Smith (smittyc)
# INC0000008          Closed  2012-05-06 10:02:01        Christa Abedi (ca102)
# INC0000009          Closed  2012-05-06 10:03:27          Kirk Rouser (kjr10)
# INC0000013          Closed  2012-05-06 10:06:27       Jeff Gentry (gentr066)
#
#                                short_description       sys_updated_on  \
# number
# INC0000000a  Urgent Workstation Issue DUH or CHC  2014-07-26 00:12:03
# INC0000006          ServiceNow initial incident.  2012-05-08 00:01:10
# INC0000008                     New employee hire  2012-05-09 00:04:07
# INC0000009                  Test Email from Kirk  2012-05-08 00:01:03
# INC0000013                           Test ticket  2012-05-06 10:46:32
#
#                                   assignment_group  calendar_duration  \
# number
# INC0000000a            Device Support-DHTS Reg6-SE              45667
# INC0000006   Support@Duke (ServiceNow App Support)             137309
# INC0000008                  [i]Device Support-DRaH             223326
# INC0000009                        Service Desk-OIT             136656
# INC0000013                Service Desk-Level 1-DRH               2405
#
#                           closed_by
# number
# INC0000000a                     NaN
# INC0000006                      NaN
# INC0000008                      NaN
# INC0000009                      NaN
# INC0000013   Jeff Gentry (gentr066)

# %%
closed_cases.tail()
# Out:
#            incident_state            opened_at                   caller_id  \
# number
# INC0013002         Closed  2012-05-15 11:01:53        Conner Belvin (wb48)
# INC0013004         Closed  2012-05-15 11:02:23      Cynthia Dallura (cd46)
# INC0013006         Closed  2012-05-15 11:02:31     Barry Foster (foste020)
# INC0013009         Closed  2012-05-15 11:03:21  Michelle Carter (carte040)
# INC0013011         Closed  2012-05-15 11:04:19     Bernice Justice (just1)
#
#                                             short_description  \
# number
# INC0013002                               NetID password reset
# INC0013004                          install/configure scanner
# INC0013006                                  DHE Account Reset
# INC0013009  Customer states that she is unable to type an ...
# INC0013011  Self Service submission for 'Phone, Line, Jack...
#
#                  sys_updated_on            assignment_group  \
# number
# INC0013002  2012-05-26 00:00:36   Service Desk-Level 1-DHTS
# INC0013004  2012-05-26 00:09:59        Service Desk-DOM-SOM
# INC0013006  2012-05-26 00:04:35   Service Desk-Level 1-DHTS
# INC0013009  2012-05-26 00:01:47   Service Desk-Level 1-DHTS
# INC0013011  2012-05-28 00:02:07  Network Services-Jack-DHTS
#
#             calendar_duration closed_by
# number
# INC0013002             910723       NaN
# INC0013004             911256       NaN
# INC0013006             910924       NaN
# INC0013009             910706       NaN
# INC0013011            1083468       NaN

# %%
closed_cases['calendar_duration'] = closed_cases['calendar_duration'] / 3600 #to get number of hours
closed_cases.head()
# Out:
#             incident_state            opened_at                    caller_id  \
# number
# INC0000000a         Closed  2014-07-14 17:59:09        Patrick Brown (pab26)
# INC0000006          Closed  2012-05-06 09:52:41  Christopher Smith (smittyc)
# INC0000008          Closed  2012-05-06 10:02:01        Christa Abedi (ca102)
# INC0000009          Closed  2012-05-06 10:03:27          Kirk Rouser (kjr10)
# INC0000013          Closed  2012-05-06 10:06:27       Jeff Gentry (gentr066)
#
#                                short_description       sys_updated_on  \
# number
# INC0000000a  Urgent Workstation Issue DUH or CHC  2014-07-26 00:12:03
# INC0000006          ServiceNow initial incident.  2012-05-08 00:01:10
# INC0000008                     New employee hire  2012-05-09 00:04:07
# INC0000009                  Test Email from Kirk  2012-05-08 00:01:03
# INC0000013                           Test ticket  2012-05-06 10:46:32
#
#                                   assignment_group  calendar_duration  \
# number
# INC0000000a            Device Support-DHTS Reg6-SE          12.685278
# INC0000006   Support@Duke (ServiceNow App Support)          38.141389
# INC0000008                  [i]Device Support-DRaH          62.035000
# INC0000009                        Service Desk-OIT          37.960000
# INC0000013                Service Desk-Level 1-DRH           0.668056
#
#                           closed_by
# number
# INC0000000a                     NaN
# INC0000006                      NaN
# INC0000008                      NaN
# INC0000009                      NaN
# INC0000013   Jeff Gentry (gentr066)

# %%
closed_cases.describe()
# Out:
#        calendar_duration
# count        9998.000000
# mean          422.552856
# std          1338.100030
# min             0.010278
# 25%           248.546528
# 50%           253.915000
# 75%           278.158819
# max         38465.432222

# %%
#plt.scatter(closed_cases.number, closed_cases.calendar_duration)
closed_cases.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1125bf0d0>]], dtype=object)

# %%
closed_cases = pd.DataFrame(rawdata[rawdata['calendar_duration'] < 5000]) #remove outliers, 5000 hours + 
closed_cases.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1130453d0>]], dtype=object)
